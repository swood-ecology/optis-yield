# %%
import nass
import pandas as pd
import numpy as np

# %%
# Assign personal API key
api = nass.NassApi('9AE46388-B868-3A35-BEA3-BA1AE1172D77')

# %%
# Generate an API query object
q = api.query()

# %%
# Pull data for all years and append
# 2005
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2005)
datTemp = q.execute()
data = pd.DataFrame(datTemp)

# 2006
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2006)
datTemp = q.execute()
datTemp = pd.DataFrame(datTemp)
data = data.append(datTemp)

# 2007
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2007)
datTemp = q.execute()
datTemp = pd.DataFrame(datTemp)
data = data.append(datTemp)

# %%
# 2008
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2008)
datTemp = q.execute()
datTemp = pd.DataFrame(datTemp)
data = data.append(datTemp)

# 2009
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2009)
datTemp = q.execute()
datTemp = pd.DataFrame(datTemp)
data = data.append(datTemp)

# 2010
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2010)
datTemp = q.execute()
datTemp = pd.DataFrame(datTemp)
data = data.append(datTemp)

# %%
# 2011
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2011)
datTemp = q.execute()
datTemp = pd.DataFrame(datTemp)
data = data.append(datTemp)

# 2012
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2012)
datTemp = q.execute()
datTemp = pd.DataFrame(datTemp)
data = data.append(datTemp)

# 2013
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2013)
datTemp = q.execute()
datTemp = pd.DataFrame(datTemp)
data = data.append(datTemp)

# %%
# 2014
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2014)
datTemp = q.execute()
datTemp = pd.DataFrame(datTemp)
data = data.append(datTemp)

# 2015
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2015)
datTemp = q.execute()
datTemp = pd.DataFrame(datTemp)
data = data.append(datTemp)

# 2016
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2016)
datTemp = q.execute()
datTemp = pd.DataFrame(datTemp)
data = data.append(datTemp)

# 2017
q.filter('commodity_desc','CORN').filter('statisticcat_desc', 'YIELD').filter('util_practice_desc','GRAIN').filter('agg_level_desc','COUNTY').filter('year',2017)
datTemp = q.execute()
datTemp = pd.DataFrame(datTemp)
data = data.append(datTemp)

# %%
# Filter out unnecessary columns
data = data.drop(columns=['week_ending', 'reference_period_desc','freq_desc', 'zip_5', 'watershed_desc', 
                          'load_time','region_desc', 'util_practice_desc', 'country_name','end_code', 
                          'watershed_code','class_desc','domaincat_desc','domain_desc',
                          'congr_district_code','source_desc'])

# %%
# Concatentate a FIPS code
data['fips'] = data['state_fips_code']+data['county_code']

# %%
# Read in DNDC data to filter
dndc = pd.read_csv('../raw-data/DNDC/county-si.csv')

# %%
print(dndc['fips'].to_string())

# %%
print(data['fips'].to_string())

# %%
# Filter NASS data by DNDC data
key = list(np.unique(dndc['fips']))

# %%
data['fips'].isin({'fips': key})

key = ['01033','01077']
type(key)
data.isin({'fips': key})
# Out:
# list

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b957b3b9a998> in <module>
# ----> 1 df_cut = df_new[
#       2              (
#       3              (df_new['l_ext']==31) |
#       4              (df_new['l_ext']==22) |
#       5              (df_new['l_ext']==30) |
#
# NameError: name 'df_new' is not defined

# %%
data
# Out:
#      agg_level_desc county_ansi   group_desc state_name state_ansi begin_code  \
# 0            COUNTY         033  FIELD CROPS    ALABAMA         01         00
# 1            COUNTY         077  FIELD CROPS    ALABAMA         01         00
# 2            COUNTY         079  FIELD CROPS    ALABAMA         01         00
# 3            COUNTY         083  FIELD CROPS    ALABAMA         01         00
# 4            COUNTY         089  FIELD CROPS    ALABAMA         01         00
# ...             ...         ...          ...        ...        ...        ...
# 1870         COUNTY              FIELD CROPS      TEXAS         48         00
# 1871         COUNTY              FIELD CROPS      TEXAS         48         00
# 1872         COUNTY         215  FIELD CROPS      TEXAS         48         00
# 1873         COUNTY         489  FIELD CROPS      TEXAS         48         00
# 1874         COUNTY              FIELD CROPS      TEXAS         48         00
#
# ...
