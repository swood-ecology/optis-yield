# %%
import pandas as pd
import numpy as np

# %%
dndc = pd.read_csv("raw-data/DNDC/county-si.csv")

# %%
dndc.head()
# Out:
#     fips county     state      scenario  crop_year      n2od  no3_leach  \
# 0  17001  Adams  Illinois  OpTIS-mapped       2005  0.880101  21.234425
# 1  17001  Adams  Illinois  OpTIS-mapped       2006  0.891116  24.798863
# 2  17001  Adams  Illinois  OpTIS-mapped       2007  0.981525  34.710393
# 3  17001  Adams  Illinois  OpTIS-mapped       2008  1.673252  67.455789
# 4  17001  Adams  Illinois  OpTIS-mapped       2009  1.390710  34.530627
#
#          dsoc       awc    n2od_gwp    dsoc_gwp         gwp
# 0  243.551822  0.205467  366.499012 -893.023347 -526.524335
# 1  166.612528  0.205509  371.086011 -610.912603 -239.826593
# 2  140.999400  0.205688  408.735250 -516.997800 -108.262550
# 3   68.980015  0.205708  696.790040 -252.926721  443.863319
# 4  144.221299  0.205903  579.131331 -528.811428   50.319903
